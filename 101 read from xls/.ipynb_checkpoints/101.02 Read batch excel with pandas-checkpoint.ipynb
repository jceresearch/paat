# %%
import pandas as pd
import glob # used to read file directories, there are alternatives: pathlib.Path.rglob or os.walk

# %%
def load_xls_from_dir(path):
    files= glob.glob(path, recursive=True)
    df= pd.DataFrame()
    for f in files:
        #Option 1: read just the first sheet of book
        #data=pd.read_excel(f) 
        #df=df.append(data, sort=False)
        #Option 2: loop through each tab in each workbook and add id fields
        xl = pd.ExcelFile(f)
        for s in xl.sheet_names:
            data=xl.parse(s)
            data["ori_file"]= f
            data["ori_sheet"]=s
            df=df.append(data, sort=False)
    return df

# %%
df= load_xls_from_dir("./test_data/batch/*.xlsx")

# %%
df
# Out:
#      Customer_ID       Date  Transaction_ID      Result  \
# 0         226369 2019-01-01               1  Authorised
# 1         473449 2019-01-01               2  Authorised
# 2         376400 2019-01-01               3  Authorised
# 3          41268 2019-01-01               4  Authorised
# 4         285513 2019-01-01               5  Authorised
# ..           ...        ...             ...         ...
# 682       408881 2019-06-30            3953  Authorised
# 683       328647 2019-06-30            3954  Authorised
# 684       312524 2019-06-30            3955  Authorised
# 685       193633 2019-06-30            3956  Authorised
# 686       133436 2019-06-30            3957    Rejected
#
#                       ori_file ori_sheet
# 0    ./test_data/batch\Q1.xlsx       Jan
# 1    ./test_data/batch\Q1.xlsx       Jan
# 2    ./test_data/batch\Q1.xlsx       Jan
# 3    ./test_data/batch\Q1.xlsx       Jan
# 4    ./test_data/batch\Q1.xlsx       Jan
# ..                         ...       ...
# 682  ./test_data/batch\Q2.xlsx       Jun
# 683  ./test_data/batch\Q2.xlsx       Jun
# 684  ./test_data/batch\Q2.xlsx       Jun
# 685  ./test_data/batch\Q2.xlsx       Jun
# 686  ./test_data/batch\Q2.xlsx       Jun
#
# [9722 rows x 6 columns]

# %%
df.columns=[x.lower() for x in df.columns.to_list()]
df.columns=df.columns.str.replace(' ','_')
df.head()
# Out:
#    customer_id       date  transaction_id      result  \
# 0       226369 2019-01-01               1  Authorised
# 1       473449 2019-01-01               2  Authorised
# 2       376400 2019-01-01               3  Authorised
# 3        41268 2019-01-01               4  Authorised
# 4       285513 2019-01-01               5  Authorised
#
#                     ori_file ori_sheet
# 0  ./test_data/batch\Q1.xlsx       Jan
# 1  ./test_data/batch\Q1.xlsx       Jan
# 2  ./test_data/batch\Q1.xlsx       Jan
# 3  ./test_data/batch\Q1.xlsx       Jan
# 4  ./test_data/batch\Q1.xlsx       Jan

# %%
df.sort_values('date', axis=0, ascending=False, inplace=True)
df[0:10]
# Out:
#      customer_id       date  transaction_id      result  \
# 686       133436 2019-06-30            3957    Rejected
# 659        34300 2019-06-30            3930  Authorised
# 657       153100 2019-06-30            3928  Authorised
# 656       489642 2019-06-30            3927  Authorised
# 655       306857 2019-06-30            3926  Authorised
# 654        94990 2019-06-30            3925  Authorised
# 653        57777 2019-06-30            3924  Authorised
# 652       330715 2019-06-30            3923  Authorised
# 651        35558 2019-06-30            3922  Authorised
# 650       136840 2019-06-30            3921  Authorised
#
#                       ori_file ori_sheet
# 686  ./test_data/batch\Q2.xlsx       Jun
# 659  ./test_data/batch\Q2.xlsx       Jun
# 657  ./test_data/batch\Q2.xlsx       Jun
# 656  ./test_data/batch\Q2.xlsx       Jun
# 655  ./test_data/batch\Q2.xlsx       Jun
# 654  ./test_data/batch\Q2.xlsx       Jun
# 653  ./test_data/batch\Q2.xlsx       Jun
# 652  ./test_data/batch\Q2.xlsx       Jun
# 651  ./test_data/batch\Q2.xlsx       Jun
# 650  ./test_data/batch\Q2.xlsx       Jun

# %% [markdown]
# Lets look for some duplicates

# %%
df[df.duplicated(keep=False)] # first full record
# Out:
# Empty DataFrame
# Columns: [customer_id, date, transaction_id, result, ori_file, ori_sheet]
# Index: []

# %%
df[df.transaction_id.duplicated(keep=False)] # transaction id
# Out:
#      customer_id       date  transaction_id      result  \
# 686       133436 2019-06-30            3957    Rejected
# 659        34300 2019-06-30            3930  Authorised
# 657       153100 2019-06-30            3928  Authorised
# 656       489642 2019-06-30            3927  Authorised
# 655       306857 2019-06-30            3926  Authorised
# ..           ...        ...             ...         ...
# 28        486103 2019-01-01              29  Authorised
# 29        329169 2019-01-01              30  Authorised
# 30        146677 2019-01-01              31  Authorised
# 31        175585 2019-01-01              32  Authorised
# 0         226369 2019-01-01               1  Authorised
#
#                       ori_file ori_sheet
# 686  ./test_data/batch\Q2.xlsx       Jun
# 659  ./test_data/batch\Q2.xlsx       Jun
# 657  ./test_data/batch\Q2.xlsx       Jun
# 656  ./test_data/batch\Q2.xlsx       Jun
# 655  ./test_data/batch\Q2.xlsx       Jun
# ..                         ...       ...
# 28   ./test_data/batch\Q1.xlsx       Jan
# 29   ./test_data/batch\Q1.xlsx       Jan
# 30   ./test_data/batch\Q1.xlsx       Jan
# 31   ./test_data/batch\Q1.xlsx       Jan
# 0    ./test_data/batch\Q1.xlsx       Jan
#
# [7914 rows x 6 columns]

# %%
df2.sort_values('Date', axis=0, ascending=False, inplace=True)
df2[0:10]
# Out:
#     Auth_ID  Date  Customer_ID
# 18  9000019     2            2
# 23  9000025     1            1
# 10  9000011     1            1
# 2   9000003     1            1
# 3   9000004     1            1
# 4   9000005     1            1
# 5   9000006     1            1
# 6   9000007     1            1
# 7   9000008     1            1
# 8   9000009     1            1

# %%
df2.to_excel("output/101_Output_Grouped.xlsx", sheet_name='Grouped')
