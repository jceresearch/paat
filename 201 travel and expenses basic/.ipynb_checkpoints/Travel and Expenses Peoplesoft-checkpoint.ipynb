# %% [markdown]
# Travel and Expenses from Peoplesoft

# %%
#!Python3

import pandas as pd
import os 
import numpy as np

from time import gmtime, strftime
import datetime

#XLS reader libraries
import xlrd 
import xlwings as xls


# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
try:
    df = pd.read_pickle("df_tmp.pickle")
except:
    print ("previous df not found")
# Out:
# previous df not found

# %% [markdown]
# We open the Excel file and list the sheets inside, just to check we are reading it properly

# %%
df=[]
input_list=[]
input_list.append("\\live\\peoplesoft\\data.xlsx")


#this is the workbook object
# this is a list of frames, we will load there the subframes and then we will "concatenate" them together
input_frames=[]
#another extra nicety we will ad some custom fields in the process, timestamp and origin sheet
ts= strftime("%Y-%m-%d %H:%M:%S")

for xlsfile in input_list:
    wb = xls.Book(xlsfile)
    #this is the pandas data frame object, we will load the workbook into the dataframe for superfast processing
    df =pd.DataFrame([])

    #as an extra nicety we will load all sheets that have the title "Name" in the cell A1 into a single dataframe
    #assuming they have the same structure, i.e. we assume a huge table split into several sheets, as sometimes we
    #get from large exports
    
    n= len(xls.sheets)

    print ("Total Sheets in worbook:"+ wb.name +" "+ str(n))

    for x in range(0, n):
        sh = wb.sheets[x]
        cellA1= sh.range("A1").value
        
        if cellA1=="Name" or sh.name =="Data":
            print ("Processing sheet " + str(x) + ":" + sh.name   ) 

            #This is equivalent to "select region" from the first cell, not sure if it works
            data = sh.range("A1").expand().value

            #data= xls.Range(sh,"A1:E100000").value
            #We add here the data from the second row,and we add as field names the first row
            # in python index starts a 0
            frame=pd.DataFrame(data[1:],columns=data[0])
            #We add here a column for the source sheet and a timestamp
            frame["SourceFile"]= xlsfile
            frame["SourceSheet"]=sh.name
            frame["Timestamp"]= ts

            input_frames.append (frame)
      
        
    wb.close()
    
df = pd.concat(input_frames, ignore_index=True)
print ("Top 10 records")
print (df[100:110])
# Out:
# Total Sheets in worbook:Data.xlsx 2
# Processing sheet 0:Data
# Top 10 records
#     Acctg_Date Expense_Business_Unit  Employee_ID  Expense_Claim_Number  \
# 100 2017-01-06                 ISCOS     728638.0               83467.0
# 101 2017-01-06                 ISCOS     728638.0               83467.0
# 102 2017-01-06                 ISCOS     728638.0               83467.0
# 103 2017-01-06                 ISCOS     728638.0               83467.0
# 104 2017-01-26                 ISCOS     744804.0               84424.0
# 105 2016-10-21                 ISCOS     729312.0               77224.0
# 106 2015-12-21                 ISCOS     734381.0               56147.0
# 107 2016-05-27                 ISCOS     747195.0               60376.0
# 108 2016-05-27                 ISCOS     747195.0               60376.0
# 109 2016-03-31                 ISCOS     735038.0               60937.0
#
#     Creation_Date            Report_Description Claim_Currency  \
# 100    2017-01-06  Meetings and Christmas Party            GBP
# 101    2017-01-06  Meetings and Christmas Party            GBP
# 102    2017-01-06  Meetings and Christmas Party            GBP
# 103    2017-01-06  Meetings and Christmas Party            GBP
# 104    2017-01-24                   BH JAN 2017            GBP
# 105    2016-10-21               Storage expense            GBP
# 106    2015-12-21   CS Reward cupboard re-stock            GBP
# 107    2016-02-26                      Expenses            GBP
# 108    2016-02-26                      Expenses            GBP
# 109    2016-03-04              Singapore Travel            GBP
#
#      Total_Claim_Amount_incl_VAT_  Total_Due_Employee_incl_VAT_  Paid_Date  \
# 100                        196.48                        196.48 2017-01-11
# 101                        196.48                        196.48 2017-01-11
# 102                        196.48                        196.48 2017-01-11
# 103                        196.48                        196.48 2017-01-11
# 104                        826.32                        826.32 2017-02-01
# 105                       2958.67                       2958.67 2016-10-26
# 106                        256.21                        256.21 2016-06-08
# 107                        948.30                        948.30 2016-06-01
# 108                        948.30                        948.30 2016-06-01
# 109                       3477.57                       3477.57 2016-04-06
#
#             ...           Distance_Rate Car_Allowance Number_of_Passengers  \
# 100         ...                     0.0          None                  0.0
# 101         ...                     0.0          None                  0.0
# 102         ...                     0.0          None                  0.0
# 103         ...                     0.0          None                  0.0
# 104         ...                     0.0          None                  0.0
# 105         ...                     0.0          None                  0.0
# 106         ...                     0.0          None                  0.0
# 107         ...                     0.0          None                  0.0
# 108         ...                     0.0          None                  0.0
# 109         ...                     0.0          None                  0.0
#
#     Number_of_Nights Authorized_Amount_Exceeded  Location_Amount_Comment  \
# 100              0.0                          N                     None
# 101              0.0                          N                     None
# 102              0.0                          N                     None
# 103              0.0                          N                     None
# 104              0.0                          N                     None
# 105              0.0                          N                     None
# 106              0.0                          N                     None
# 107              0.0                          N                     None
# 108              0.0                          N                     None
# 109              0.0                          N                     None
#
#     Comments                  SourceFile  SourceSheet            Timestamp
# 100     None  \live\peoplesoft\data.xlsx         Data  2017-05-23 16:08:23
# 101     None  \live\peoplesoft\data.xlsx         Data  2017-05-23 16:08:23
# 102     None  \live\peoplesoft\data.xlsx         Data  2017-05-23 16:08:23
# 103     None  \live\peoplesoft\data.xlsx         Data  2017-05-23 16:08:23
# 104     None  \live\peoplesoft\data.xlsx         Data  2017-05-23 16:08:23
# 105     None  \live\peoplesoft\data.xlsx         Data  2017-05-23 16:08:23
# 106     None  \live\peoplesoft\data.xlsx         Data  2017-05-23 16:08:23
# 107     None  \live\peoplesoft\data.xlsx         Data  2017-05-23 16:08:23
# 108     None  \live\peoplesoft\data.xlsx         Data  2017-05-23 16:08:23
# 109     None  \live\peoplesoft\data.xlsx         Data  2017-05-23 16:08:23
#
# [10 rows x 44 columns]

# %%
#Here we concatenate the multiple dataframes we created , one per sheet
# the ignore_index option is so that the main index is recreated so each row will have a unique ID 
df = pd.concat(input_frames, ignore_index=True)
print ("Top records")
print (df[0:1])
# Out:
# Top records
#   Acctg_Date Expense_Business_Unit  Employee_ID  Expense_Claim_Number  \
# 0 2016-03-30                 ISCOS     734216.0               62602.0
#
#   Creation_Date Report_Description Claim_Currency  \
# 0    2016-03-30  Flowers for Diana            GBP
#
#    Total_Claim_Amount_incl_VAT_  Total_Due_Employee_incl_VAT_  Paid_Date  \
# 0                          24.0                          24.0 2016-04-06
#
#           ...           Distance_Rate Car_Allowance Number_of_Passengers  \
# 0         ...                     0.0          None                  0.0
#
#   Number_of_Nights Authorized_Amount_Exceeded  Location_Amount_Comment  \
# 0              0.0                          N                     None
#
#   Comments                  SourceFile  SourceSheet            Timestamp
# 0     None  \live\peoplesoft\data.xlsx         Data  2017-05-23 16:08:23
#
# [1 rows x 44 columns]

# %%
df.to_pickle(("df_tmp.pickle"))

# %%
#f.Employee_ID
df.dtypes
# Out:
# Acctg_Date                      datetime64[ns]
# Expense_Business_Unit                   object
# Employee_ID                            float64
# Expense_Claim_Number                   float64
# Creation_Date                   datetime64[ns]
# Report_Description                      object
# Claim_Currency                          object
# Total_Claim_Amount_incl_VAT_           float64
# Total_Due_Employee_incl_VAT_           float64
# Paid_Date                       datetime64[ns]
# Line_N                                 float64
# Transaction_Date                datetime64[ns]
# No_Receipt_Flg                          object
# Journal_ID                              object
# Journal_Date                    datetime64[ns]
# Journal_Amt                            float64
# GL_Business_Unit                        object
# Cost_Centre                            float64
# GL_Account_Code                        float64
# GL_Account_Code_Description             object
# Project_Code                            object
# Expense_Type_Description                object
# Expense_Long_Description                object
# Transaction_Currency                    object
# Transaction_Amount                     float64
# Transaction_VAT                        float64
# Monetary_Currency                       object
# Monetary_Amount                        float64
# Monetary_VAT                           float64
# No_VAT_Receipt_Flg                      object
# Destination_Location                    object
# Originating_Location                    object
# Transport_Type                          object
# Distance_Traveled                      float64
# Distance_Rate                          float64
# Car_Allowance                           object
# Number_of_Passengers                   float64
# Number_of_Nights                       float64
# Authorized_Amount_Exceeded              object
# Location_Amount_Comment                 object
# Comments                                object
# SourceFile                              object
# SourceSheet                             object
# Timestamp                               object
# dtype: object

# %%
#Conversion and renaming 
df.rename(columns={'Journal_Amt' : 'Amount'}, inplace=True)




#df['Expenses'] = pd.to_numeric(round(df['Expenses'])
#df['Expenses']= df['Expenses'].fillna(0) #To convert any blanks/NaN to zero, you may want to check those before killing them
#print ("Top 10 records")
#print (df[0:10])

df.dtypes
# Out:
# Acctg_Date                      datetime64[ns]
# Expense_Business_Unit                   object
# Employee_ID                            float64
# Expense_Claim_Number                   float64
# Creation_Date                   datetime64[ns]
# Report_Description                      object
# Claim_Currency                          object
# Total_Claim_Amount_incl_VAT_           float64
# Total_Due_Employee_incl_VAT_           float64
# Paid_Date                       datetime64[ns]
# Line_N                                 float64
# Transaction_Date                datetime64[ns]
# No_Receipt_Flg                          object
# Journal_ID                              object
# Journal_Date                    datetime64[ns]
# Amount                                 float64
# GL_Business_Unit                        object
# Cost_Centre                            float64
# GL_Account_Code                        float64
# GL_Account_Code_Description             object
# Project_Code                            object
# Expense_Type_Description                object
# Expense_Long_Description                object
# Transaction_Currency                    object
# Transaction_Amount                     float64
# Transaction_VAT                        float64
# Monetary_Currency                       object
# Monetary_Amount                        float64
# Monetary_VAT                           float64
# No_VAT_Receipt_Flg                      object
# Destination_Location                    object
# Originating_Location                    object
# Transport_Type                          object
# Distance_Traveled                      float64
# Distance_Rate                          float64
# Car_Allowance                           object
# Number_of_Passengers                   float64
# Number_of_Nights                       float64
# Authorized_Amount_Exceeded              object
# Location_Amount_Comment                 object
# Comments                                object
# SourceFile                              object
# SourceSheet                             object
# Timestamp                               object
# dtype: object

# %%
def label_race (row):
   if row['eri_hispanic'] == 1 :
      return 'Hispanic'

df.apply (lambda row: test_1 (row),axis=1)

# %%
print ("Record count (non null):")
print(df.count())
print ("Min value:"+ str(df["Amount"].min()))
print ("Max value:" + str(df["Amount"].max()))
# Out:
# Record count (non null):
# Acctg_Date                      13674
# Expense_Business_Unit           13674
# Employee_ID                     13674
# Expense_Claim_Number            13674
# Creation_Date                   13674
# Report_Description              13674
# Claim_Currency                  13674
# Total_Claim_Amount_incl_VAT_    13674
# Total_Due_Employee_incl_VAT_    13674
# Paid_Date                       13672
# Line_N                          13674
# Transaction_Date                13674
# No_Receipt_Flg                    758
# Journal_ID                      13674
# Journal_Date                    13674
# Amount                          13674
# GL_Business_Unit                13674
# Cost_Centre                     13674
# GL_Account_Code                 13674
# GL_Account_Code_Description     13674
# Project_Code                      128
# Expense_Type_Description        13674
# Expense_Long_Description        13674
# Transaction_Currency            13674
# Transaction_Amount              13674
# Transaction_VAT                 13674
# Monetary_Currency               13674
# Monetary_Amount                 13674
# Monetary_VAT                    13674
# No_VAT_Receipt_Flg               1194
# Destination_Location            13582
# Originating_Location             6726
# Transport_Type                    623
# Distance_Traveled               13674
# Distance_Rate                   13674
# Car_Allowance                     623
# Number_of_Passengers            13674
# Number_of_Nights                13674
# Authorized_Amount_Exceeded      13674
# Location_Amount_Comment           245
# Comments                            0
# SourceFile                      13674
# SourceSheet                     13674
# Timestamp                       13674
# dtype: int64
# Min value:-156.0
# Max value:7598.91

# %%
#print ("Blanks or negatives")
# Use this ifyou have trouble with field names with spaces etc
# print (df[(df['Expenses']<=0 )|(df['Expenses']>100000)])

df[df.Amount <=0].count()
# Out:
# Acctg_Date                      7
# Expense_Business_Unit           7
# Employee_ID                     7
# Expense_Claim_Number            7
# Creation_Date                   7
# Report_Description              7
# Claim_Currency                  7
# Total_Claim_Amount_incl_VAT_    7
# Total_Due_Employee_incl_VAT_    7
# Paid_Date                       6
# Line_N                          7
# Transaction_Date                7
# No_Receipt_Flg                  0
# Journal_ID                      7
# Journal_Date                    7
# Amount                          7
# GL_Business_Unit                7
# Cost_Centre                     7
# GL_Account_Code                 7
# GL_Account_Code_Description     7
# Project_Code                    0
# Expense_Type_Description        7
# Expense_Long_Description        7
# Transaction_Currency            7
# Transaction_Amount              7
# Transaction_VAT                 7
# Monetary_Currency               7
# Monetary_Amount                 7
# Monetary_VAT                    7
# No_VAT_Receipt_Flg              0
# Destination_Location            7
# Originating_Location            2
# Transport_Type                  0
# Distance_Traveled               7
# Distance_Rate                   7
# Car_Allowance                   0
# Number_of_Passengers            7
# Number_of_Nights                7
# Authorized_Amount_Exceeded      7
# Location_Amount_Comment         0
# Comments                        0
# SourceFile                      7
# SourceSheet                     7
# Timestamp                       7
# dtype: int64

# %%
df.Employee_ID.value_counts()[:5]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_slice_bound(self, label, side, kind)
#    3434             try:
# -> 3435                 return self._searchsorted_monotonic(label, side)
#    3436             except ValueError:
#
# C:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in _searchsorted_monotonic(self, label, side)
#    3393
# -> 3394         raise ValueError('index must be monotonic increasing or decreasing')
#    3395
#
# ValueError: index must be monotonic increasing or decreasing
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-93ed299a3cfa> in <module>()
# ----> 1 df.Employee_ID.value_counts()[:5]
#
# C:\Anaconda\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     640             key = check_bool_indexer(self.index, key)
#     641
# --> 642         return self._get_with(key)
#     643
#     644     def _get_with(self, key):
#
# C:\Anaconda\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#     645         # other: fancy integer or otherwise
#     646         if isinstance(key, slice):
# --> 647             indexer = self.index._convert_slice_indexer(key, kind='getitem')
#     648             return self._get_values(indexer)
#     649         elif isinstance(key, ABCDataFrame):
#
# C:\Anaconda\lib\site-packages\pandas\core\indexes\numeric.py in _convert_slice_indexer(self, key, kind)
#     300
#     301         # translate to locations
# --> 302         return self.slice_indexer(key.start, key.stop, key.step, kind=kind)
#     303
#     304     def _format_native_types(self, na_rep='', float_format=None, decimal='.',
#
# C:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in slice_indexer(self, start, end, step, kind)
#    3299         """
#    3300         start_slice, end_slice = self.slice_locs(start, end, step=step,
# -> 3301                                                  kind=kind)
#    3302
#    3303         # return a slice
#
# C:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in slice_locs(self, start, end, step, kind)
#    3493         end_slice = None
#    3494         if end is not None:
# -> 3495             end_slice = self.get_slice_bound(end, 'right', kind)
#    3496         if end_slice is None:
#    3497             end_slice = len(self)
#
# C:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_slice_bound(self, label, side, kind)
#    3436             except ValueError:
#    3437                 # raise the original KeyError
# -> 3438                 raise err
#    3439
#    3440         if isinstance(slc, np.ndarray):
#
# C:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_slice_bound(self, label, side, kind)
#    3430         # we need to look up the label
#    3431         try:
# -> 3432             slc = self._get_loc_only_exact_matches(label)
#    3433         except KeyError as err:
#    3434             try:
#
# C:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in _get_loc_only_exact_matches(self, key)
#    3399         get_slice_bound.
#    3400         """
# -> 3401         return self.get_loc(key)
#    3402
#    3403     def get_slice_bound(self, label, side, kind):
#
# C:\Anaconda\lib\site-packages\pandas\core\indexes\numeric.py in get_loc(self, key, method, tolerance)
#     374             pass
#     375         return super(Float64Index, self).get_loc(key, method=method,
# --> 376                                                  tolerance=tolerance)
#     377
#     378     @cache_readonly
#
# C:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item (pandas\_libs\hashtable.c:7353)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item (pandas\_libs\hashtable.c:7297)()
#
# KeyError: 5.0

# %%
#http://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/
df.groupby('Employee_ID')['Amount'].sum().nlargest(10)
# Out:
# Employee_ID
# 748304.0    33261.34
# 747240.0    33217.00
# 746105.0    33053.60
# 746579.0    28240.73
# 748932.0    27359.21
# 740923.0    25995.68
# 397652.0    21878.98
# 302493.0    18398.96
# 749825.0    16871.59
# 745945.0    14861.59
# Name: Amount, dtype: float64

# %%
df_grouped = df.groupby('Employee_ID')['Amount'].sum().sort_values(ascending=False).to_frame()
df_grouped2 = df.groupby('Employee_ID')['Amount'].max().sort_values(ascending=False).to_frame()

df_grouped2= df_grouped2[df_grouped2>200]
df_grouped2
# Out:
#               Amount
# Employee_ID
# 746579.0     7598.91
# 745218.0     5347.11
# 749825.0     4089.11
# 744150.0     3897.75
# 748304.0     3836.98
# 735038.0     3250.79
# 726774.0     3238.70
# 748907.0     3160.00
# 302493.0     3132.99
# 729312.0     2958.67
# 740923.0     2916.26
# 745049.0     2894.42
# 717169.0     2817.78
# 747240.0     2508.00
# 746578.0     2321.15
# 746092.0     1959.34
# 748932.0     1850.61
# 736196.0     1833.51
# 746105.0     1828.75
# 747667.0     1791.00
# 748625.0     1786.84
# 731710.0     1762.56
# 729198.0     1701.89
# 746866.0     1675.84
# 741314.0     1605.74
# 191292.0     1510.29
# 712684.0     1491.27
# 748579.0     1468.42
# 747347.0     1432.13
# 725980.0     1427.37
# ...              ...
# 746776.0         NaN
# 742711.0         NaN
# 720255.0         NaN
# 743760.0         NaN
# 725073.0         NaN
# 752596.0         NaN
# 729294.0         NaN
# 735759.0         NaN
# 751617.0         NaN
# 748746.0         NaN
# 723139.0         NaN
# 723656.0         NaN
# 715131.0         NaN
# 748480.0         NaN
# 501394.0         NaN
# 752416.0         NaN
# 752360.0         NaN
# 728100.0         NaN
# 622589.0         NaN
# 719964.0         NaN
# 743563.0         NaN
# 720389.0         NaN
# 736157.0         NaN
# 748475.0         NaN
# 701712.0         NaN
# 741175.0         NaN
# 716253.0         NaN
# 723492.0         NaN
# 737027.0         NaN
# 742974.0         NaN
#
# [386 rows x 1 columns]

# %%
#to read: https://medium.com/@captain_eli/3-ways-to-make-interactive-graphs-in-jupyter-notebooks-154cbb4796a9#.hd4p9g82i

# %matplotlib notebook
import matplotlib  


#df_grouped[df_grouped.Amount>2000].plot(kind='barh', rot=0)
df_grouped.plot(kind='hist', bins=20)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
def leading_digit(x,dig=1):
    x= str(abs(x))
    out= int(x[dig-1])
    return out
df['D1']=df['Amount'].apply(leading_digit)

benf = df.groupby('D1')['D1'].count().to_frame()                 
benf= benf.iloc[1:] # We cannot compute benford for zero
benf['Benford']=np.log10(1+(1/np.arange(1,10)))
total= df['D1'].count()
print(total)
benf['Actual']=benf['D1']/total
benf['Diff']= abs(benf['Benford']-benf['Actual'])
print(benf)

benf[['Benford','Actual']].plot(kind='bar')
# Out:
# 13674
#       D1   Benford    Actual      Diff
# D1
# 1   3619  0.301030  0.264663  0.036367
# 2   2197  0.176091  0.160670  0.015421
# 3   1898  0.124939  0.138804  0.013865
# 4   1457  0.096910  0.106553  0.009643
# 5   1619  0.079181  0.118400  0.039219
# 6    945  0.066947  0.069109  0.002162
# 7    613  0.057992  0.044830  0.013162
# 8    655  0.051153  0.047901  0.003251
# 9    536  0.045757  0.039198  0.006559
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
df.groupby('Employee_ID')['D1'].value_counts(sort=False, normalize=True).to_frame()
# Out:
#                       D1
# Employee_ID D1
# 169307.0    1   0.014286
#             3   0.014286
#             4   0.014286
#             6   0.957143
# 191292.0    1   0.217391
#             2   0.608696
#             5   0.043478
#             6   0.086957
#             8   0.043478
# 256586.0    1   0.222222
#             2   0.027778
#             3   0.083333
#             4   0.111111
#             5   0.444444
#             6   0.027778
#             7   0.027778
#             8   0.055556
# 263935.0    1   0.062500
#             2   0.062500
#             3   0.375000
#             5   0.312500
#             6   0.062500
#             7   0.125000
# 290384.0    2   1.000000
# 294874.0    1   0.666667
#             6   0.333333
# 302493.0    1   0.335227
#             2   0.136364
#             3   0.176136
#             4   0.085227
# ...                  ...
# 751891.0    5   0.125000
#             8   0.125000
# 752360.0    1   1.000000
# 752412.0    1   0.500000
#             2   0.500000
# 752416.0    1   1.000000
# 752523.0    4   0.363636
#             5   0.636364
# 752596.0    2   1.000000
# 752659.0    1   0.176471
#             2   0.058824
#             3   0.764706
# 752676.0    1   0.038462
#             2   0.076923
#             3   0.057692
#             4   0.250000
#             5   0.230769
#             6   0.115385
#             8   0.211538
#             9   0.019231
# 752955.0    1   0.500000
#             2   0.166667
#             3   0.166667
#             8   0.166667
# 753028.0    1   0.111111
#             2   0.111111
#             3   0.555556
#             4   0.222222
# 753358.0    4   0.500000
#             8   0.500000
#
# [1914 rows x 1 columns]

# %%
# This is an optional command to set the index, if we had some column that can act as index, otherwise, we get the default row number  on import
#df.set_index("Name", inplace=True, drop=False)

# %%
#Now we operate on the DF
dupli_df= df[df.duplicated(['Name','Date', 'Expenses'], keep=False)].sort_values(by=["Expenses"])
print (len(dupli_df))
print  (dupli_df[0:100])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 'Name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-67a0d0302607> in <module>()
#       1 #Now we operate on the DF
# ----> 2 dupli_df= df[df.duplicated(['Name','Date', 'Expenses'], keep=False)].sort_values(by=["Expenses"])
#       3 print (len(dupli_df))
#       4 print  (dupli_df[0:100])
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in duplicated(self, subset, keep)
#    3240
#    3241         vals = (self[col].values for col in subset)
# -> 3242         labels, shape = map(list, zip(*map(f, vals)))
#    3243
#    3244         ids = get_group_index(labels, shape, sort=False, xnull=False)
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in <genexpr>(.0)
#    3239             subset = subset,
#    3240
# -> 3241         vals = (self[col].values for col in subset)
#    3242         labels, shape = map(list, zip(*map(f, vals)))
#    3243
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1532         res = cache.get(item)
#    1533         if res is None:
# -> 1534             values = self._data.get(item)
#    1535             res = self._box_item_values(item, values)
#    1536             cache[item] = res
#
# C:\Anaconda\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 'Name'

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.

# Delete any previous output
try:
    os.remove('test_duplicates.xlsx')
except:
    #Do nothing we dont have the file
    print ("Nothing to delete")
    
    
#!ls testdata
# Out:
# Nothing to delete
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
#We write the new excel , dumping the dataframe
try:
    writer = pd.ExcelWriter('test_duplicates.xlsx', engine='xlsxwriter')
    dupli_df.to_excel(writer, sheet_name='Sheet1')
except:
    print ("error creating/saving excel file")
#!ls testdata
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# Now we just open it to test it worked

book = xlrd.open_workbook('/test_duplicates.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-0ef16b85656f> in <module>()
#       1 # Now we just open it to test it worked
#       2
# ----> 3 book = xlrd.open_workbook('/test_duplicates.xlsx')
#
# C:\Anaconda\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     393         peek = file_contents[:peeksz]
#     394     else:
# --> 395         with open(filename, "rb") as f:
#     396             peek = f.read(peeksz)
#     397     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: '/test_duplicates.xlsx'

# %%
xl_sheet = book.sheet_by_index(0)
#Alternatively:
#xl_sheet = book.sheet_by_name('Sheet1')

num_cols = xl_sheet.ncols   # Number of columns

for row_idx in range(0, xl_sheet.nrows):    # Iterate through rows
    print ('-'*40)
    print ('Row: %s' % row_idx)   # Print row number
    for col_idx in range(0, num_cols):  # Iterate through columns
        cell_obj = xl_sheet.cell(row_idx, col_idx)  # Get cell object by row, col
        print ('Column: [%s] cell_obj: [%s]' % (col_idx, cell_obj))
# Out:
# ----------------------------------------
# Row: 0
# Column: [0] cell_obj: [empty:'']
# Column: [1] cell_obj: [text:'Name']
# Column: [2] cell_obj: [text:'Title']
# Column: [3] cell_obj: [text:'Expenses']
# Column: [4] cell_obj: [text:'Date']
# Column: [5] cell_obj: [text:'Date Claim']
# Column: [6] cell_obj: [text:'CostCentre']
# Column: [7] cell_obj: [text:'ExpenseType']
# Column: [8] cell_obj: [text:'SourceSheet']
# Column: [9] cell_obj: [text:'Timestamp']
# ----------------------------------------
# Row: 1
# Column: [0] cell_obj: [number:152.0]
# Column: [1] cell_obj: [text:'Michaela']
# Column: [2] cell_obj: [text:'Senior']
# Column: [3] cell_obj: [number:300.0]
# Column: [4] cell_obj: [xldate:42114.0]
# Column: [5] cell_obj: [xldate:42124.0]
# Column: [6] cell_obj: [number:1002.0]
# Column: [7] cell_obj: [number:9.0]
# Column: [8] cell_obj: [text:'Events']
# Column: [9] cell_obj: [text:'2017-02-06 20:45:25']
# ----------------------------------------
# Row: 2
# Column: [0] cell_obj: [number:271.0]
# Column: [1] cell_obj: [text:'Michaela']
# Column: [2] cell_obj: [text:'Senior']
# Column: [3] cell_obj: [number:300.0]
# Column: [4] cell_obj: [xldate:42114.0]
# Column: [5] cell_obj: [xldate:42154.0]
# Column: [6] cell_obj: [number:1003.0]
# Column: [7] cell_obj: [number:10.0]
# Column: [8] cell_obj: [text:'Other']
# Column: [9] cell_obj: [text:'2017-02-06 20:45:25']
# ----------------------------------------
# Row: 3
# Column: [0] cell_obj: [number:149.0]
# Column: [1] cell_obj: [text:'Peter']
# Column: [2] cell_obj: [text:'Manager']
# Column: [3] cell_obj: [number:2000.0]
# Column: [4] cell_obj: [xldate:42247.0]
# Column: [5] cell_obj: [xldate:42337.0]
# Column: [6] cell_obj: [number:1002.0]
# Column: [7] cell_obj: [number:13.0]
# Column: [8] cell_obj: [text:'Events']
# Column: [9] cell_obj: [text:'2017-02-06 20:45:25']
# ----------------------------------------
# Row: 4
# Column: [0] cell_obj: [number:275.0]
# Column: [1] cell_obj: [text:'Peter']
# Column: [2] cell_obj: [text:'Manager']
# Column: [3] cell_obj: [number:2000.0]
# Column: [4] cell_obj: [xldate:42247.0]
# Column: [5] cell_obj: [xldate:42287.0]
# Column: [6] cell_obj: [number:1003.0]
# Column: [7] cell_obj: [number:13.0]
# Column: [8] cell_obj: [text:'Other']
# Column: [9] cell_obj: [text:'2017-02-06 20:45:25']
