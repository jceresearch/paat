# %%
# This is important: to process XLS we use XLWINGS library, but if you have issues with it
# you might as well use XLRD library which looks like more low level, but probably more stable

import xlwings as xls

import os
import numpy as np
import pandas as pd
import imp
from time import gmtime, strftime

# %%
inputlist=[]
inputlist.append("testdata\example_expenses01.xlsx")
inputlist.append("testdata\example_expenses02.xlsx")

# %% [markdown]
# Here we demonstrate how to load tables from several excel sheets (from a single workbook) into a single dataframe
# Bear in mind that I found xlwings had issues with reading very large xls files, give it a try but if it fails try another reader.

# %%
#this is the workbook object
# this is a list of frames, we will load there the subframes and then we will "concatenate" them together
input_frames=[]
#another extra nicety we will ad some custom fields in the process, timestamp and origin sheet
ts= strftime("%Y-%m-%d %H:%M:%S")

for xlsfile in inputlist:
    wb = xls.Book(xlsfile)
    #this is the pandas data frame object, we will load the workbook into the dataframe for superfast processing
    df =pd.DataFrame([])

    #as an extra nicety we will load all sheets that have the title "Name" in the cell A1 into a single dataframe
    #assuming they have the same structure, i.e. we assume a huge table split into several sheets, as sometimes we
    #get from large exports
    
    n= len(xls.sheets)

    print ("Total Sheets in worbook:"+ wb.name +" "+ str(n))

    for x in range(0, n):
        sh = wb.sheets[x]
        cellA1= sh.range("A1").value
        
        if cellA1=="Name" or sh.name =="Data":
            print ("Processing sheet " + str(x) + ":" + sh.name   ) 

            #This is equivalent to "select region" from the first cell, not sure if it works
            data = sh.range("A1").expand().value

            #data= xls.Range(sh,"A1:E100000").value
            #We add here the data from the second row,and we add as field names the first row
            # in python index starts a 0
            frame=pd.DataFrame(data[1:],columns=data[0])
            #We add here a column for the source sheet and a timestamp
            frame["SourceFile"]= xlsfile
            frame["SourceSheet"]=sh.name
            frame["Timestamp"]= ts

            input_frames.append (frame)
      
        
    wb.close()
    
df = pd.concat(input_frames, ignore_index=True)
print ("Top 10 records")
print (df[0:10])
# Out:
# Total Sheets in worbook:example_expenses01.xlsx 2
# Processing sheet 0:AuditTrips
# Total Sheets in worbook:example_expenses02.xlsx 3
# Processing sheet 0:Events
# Processing sheet 1:Other
# Top 10 records
#      Name    Title  Expenses       Date Date Claim  CostCentre  ExpenseType  \
# 0    John   Senior    1000.0 2014-08-15 2014-09-24      1001.0          8.0
# 1   Peter  Manager    1500.0 2014-07-01 2014-08-30      1001.0         13.0
# 2    Arne   Senior      -1.0 2014-07-01 2014-08-10      1001.0         13.0
# 3   Hiten   Senior       NaN 2015-01-01 2015-02-10      1001.0          8.0
# 4  Najwan   Senior     830.0 2015-10-01 2015-11-10      1001.0          8.0
# 5   Peter  Manager    3000.0 2015-11-30 2016-01-09      1001.0          3.0
# 6    John   Senior      14.0 2014-08-15 2014-09-24      1001.0          7.0
# 7   Peter  Manager    4436.0 2014-07-01 2014-08-30      1001.0          1.0
# 8    Arne   Senior     299.0 2014-07-01 2014-08-10      1001.0          5.0
# 9   Hiten   Senior      34.0 2015-01-01 2015-02-10      1001.0          3.0
#
#                          SourceFile SourceSheet            Timestamp
# 0  testdata\example_expenses01.xlsx  AuditTrips  2017-05-08 20:09:14
# 1  testdata\example_expenses01.xlsx  AuditTrips  2017-05-08 20:09:14
# 2  testdata\example_expenses01.xlsx  AuditTrips  2017-05-08 20:09:14
# 3  testdata\example_expenses01.xlsx  AuditTrips  2017-05-08 20:09:14
# 4  testdata\example_expenses01.xlsx  AuditTrips  2017-05-08 20:09:14
# 5  testdata\example_expenses01.xlsx  AuditTrips  2017-05-08 20:09:14
# 6  testdata\example_expenses01.xlsx  AuditTrips  2017-05-08 20:09:14
# 7  testdata\example_expenses01.xlsx  AuditTrips  2017-05-08 20:09:14
# 8  testdata\example_expenses01.xlsx  AuditTrips  2017-05-08 20:09:14
# 9  testdata\example_expenses01.xlsx  AuditTrips  2017-05-08 20:09:14

# %% [markdown]
# # Overall totals and reconciliation checks (Group By)

# %%
print ("Record count (non null):")
print (df.count())
print ("Min value:"+ str(df["Expenses"].min()))
print ("Max value:" + str(df["Expenses"].max()))
print ("Records per person:" )
df['Name'].value_counts()
print ("Totals per person:")
df.groupby('Name')['Expenses'].sum()
# Out:
# Record count (non null):
# Name           451
# Title          451
# Expenses       450
# Date           451
# Date Claim     451
# CostCentre     451
# ExpenseType    451
# SourceFile     451
# SourceSheet    451
# Timestamp      451
# dtype: int64
# Min value:-1.0
# Max value:4436.0
# Records per person:
# Totals per person:
# Name
# Anshu        2458.7
# Arne         7583.9
# Arpad        4711.5
# Frank        1310.3
# Hiten        4322.5
# John        12553.9
# Juan          260.0
# Laura        5092.5
# Mary         1460.0
# Matthew      5517.9
# Melany        469.5
# Michaela    19467.3
# Najwan       1598.1
# Peter       21168.2
# Roshan        981.7
# Vishal       4427.0
# Name: Expenses, dtype: float64

# %% [markdown]
# Here we demonstrate how aggregation works.
# This is a fairly complex case where we define a structure of dictionaries with the original fields and then the computation in pairs of "name:function" eg. "min_expenses:min"
# Simpler aggregation is also demonstrated

# %%
df.groupby(['Name']).agg({'Expenses':{'min_expenses':'min', 'max_expenses':'max', 'total_expenses':'sum'},'Name': 'count', 'Date': {'First_date': 'min'}})
# Out:
#              Expenses                              Name       Date
#          min_expenses max_expenses total_expenses count First_date
# Name
# Anshu            45.1       1000.0         2458.7    10 2014-08-15
# Arne             -1.0       2000.0         7583.9    32 2014-07-01
# Arpad            11.8       1500.0         4711.5    23 2014-07-01
# Frank           209.9       1100.4         1310.3     2 2015-01-01
# Hiten            34.0       2000.0         4322.5    16 2015-01-01
# John             14.0       1000.0        12553.9    71 2014-08-15
# Juan             23.0        237.0          260.0     2 2015-10-01
# Laura            11.1        291.7         5092.5    37 2015-01-03
# Mary             79.0        277.7         1460.0    10 2015-01-13
# Matthew          16.3       2000.0         5517.9    28 2015-01-29
# Melany           -1.0        220.4          469.5     5 2014-07-01
# Michaela          4.3        300.0        19467.3   124 2015-01-12
# Najwan           53.6        830.0         1598.1     7 2015-01-06
# Peter             3.1       4436.0        21168.2    68 2014-07-01
# Roshan           54.4        211.2          981.7     6 2015-01-01
# 167  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 169  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 170  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 171  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 172  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 174  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 175  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 178  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 179  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 180  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 182  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 186  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 187  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 188  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 192  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 193  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 198  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 199  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# ..                                ...         ...                  ...
# 216  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 218  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 220  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 228  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 229  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 231  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 232  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 233  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 234  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 235  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 236  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 237  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 240  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 241  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 243  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 245  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 246  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 247  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 248  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 249  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 251  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 253  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 255  testdata\example_expenses02.xlsx      Events  2017-05-08 20:09:14
# 25           4.0  testdata\example_expenses01.xlsx  AuditTrips
# 26           8.0  testdata\example_expenses01.xlsx  AuditTrips
# 27           7.0  testdata\example_expenses01.xlsx  AuditTrips
# 28           5.0  testdata\example_expenses01.xlsx  AuditTrips
# 29           4.0  testdata\example_expenses01.xlsx  AuditTrips
# 30          11.0  testdata\example_expenses01.xlsx  AuditTrips
# 31           8.0  testdata\example_expenses01.xlsx  AuditTrips
# 32           8.0  testdata\example_expenses01.xlsx  AuditTrips
# 33          13.0  testdata\example_expenses01.xlsx  AuditTrips
# 34           2.0  testdata\example_expenses01.xlsx  AuditTrips
# 35           4.0  testdata\example_expenses01.xlsx  AuditTrips
# 36           2.0  testdata\example_expenses01.xlsx  AuditTrips
# 37           7.0  testdata\example_expenses01.xlsx  AuditTrips
# ..           ...                               ...         ...
# 421          8.0  testdata\example_expenses02.xlsx       Other
# 422         10.0  testdata\example_expenses02.xlsx       Other
# 423          5.0  testdata\example_expenses02.xlsx       Other
# 424          9.0  testdata\example_expenses02.xlsx       Other
# 425          6.0  testdata\example_expenses02.xlsx       Other
# 426          4.0  testdata\example_expenses02.xlsx       Other
# 427          1.0  testdata\example_expenses02.xlsx       Other
# 428          3.0  testdata\example_expenses02.xlsx       Other
# 429          2.0  testdata\example_expenses02.xlsx       Other
# 430          3.0  testdata\example_expenses02.xlsx       Other
# 431         12.0  testdata\example_expenses02.xlsx       Other
# 432          4.0  testdata\example_expenses02.xlsx       Other
# 433         12.0  testdata\example_expenses02.xlsx       Other
# 434          1.0  testdata\example_expenses02.xlsx       Other
# 435          7.0  testdata\example_expenses02.xlsx       Other
# 436          2.0  testdata\example_expenses02.xlsx       Other
# 437          9.0  testdata\example_expenses02.xlsx       Other
# 438          7.0  testdata\example_expenses02.xlsx       Other
# 439          3.0  testdata\example_expenses02.xlsx       Other
# 440          1.0  testdata\example_expenses02.xlsx       Other
# 441         12.0  testdata\example_expenses02.xlsx       Other
# 442          3.0  testdata\example_expenses02.xlsx       Other
# 443          4.0  testdata\example_expenses02.xlsx       Other
# 444          7.0  testdata\example_expenses02.xlsx       Other
# 445          2.0  testdata\example_expenses02.xlsx       Other
# 446         12.0  testdata\example_expenses02.xlsx       Other
# 447          3.0  testdata\example_expenses02.xlsx       Other
# 448          2.0  testdata\example_expenses02.xlsx       Other
# 449          2.0  testdata\example_expenses02.xlsx       Other
# 450          7.0  testdata\example_expenses02.xlsx       Other
#
#                Timestamp
# 4    2017-05-08 20:09:14
# 5    2017-05-08 20:09:14
# 10   2017-05-08 20:09:14
# 11   2017-05-08 20:09:14
# 12   2017-05-08 20:09:14
# 13   2017-05-08 20:09:14
# 14   2017-05-08 20:09:14
# 15   2017-05-08 20:09:14
# 16   2017-05-08 20:09:14
# 17   2017-05-08 20:09:14
# 18   2017-05-08 20:09:14
# 19   2017-05-08 20:09:14
# 20   2017-05-08 20:09:14
# 21   2017-05-08 20:09:14
# 22   2017-05-08 20:09:14
# 146          9.0  testdata\example_expenses02.xlsx      Events
# 149          4.0  testdata\example_expenses02.xlsx      Events
# 150         10.0  testdata\example_expenses02.xlsx      Events
# 151         11.0  testdata\example_expenses02.xlsx      Events
# 152          2.0  testdata\example_expenses02.xlsx      Events
# 271         11.0  testdata\example_expenses02.xlsx       Other
# 275         13.0  testdata\example_expenses02.xlsx       Other
#
#                Timestamp
# 0    2017-05-08 20:09:14
# 1    2017-05-08 20:09:14
# 2    2017-05-08 20:09:14
# 144  2017-05-08 20:09:14
# 145  2017-05-08 20:09:14
# 146  2017-05-08 20:09:14
# 149  2017-05-08 20:09:14
# 150  2017-05-08 20:09:14
# 151  2017-05-08 20:09:14
# 152  2017-05-08 20:09:14
# 271  2017-05-08 20:09:14
# 275  2017-05-08 20:09:14

# %%
#Test for duplicate expenses , we now go to detail
dfex03=df[df.duplicated(["Name","Title","Date","Expenses"], keep=False)]
dfex03
# Out:
#          Name    Title  Expenses       Date Date Claim  CostCentre  \
# 149     Peter  Manager    2000.0 2015-08-31 2015-11-29      1002.0
# 152  Michaela   Senior     300.0 2015-04-20 2015-04-30      1002.0
# 271  Michaela   Senior     300.0 2015-04-20 2015-05-30      1003.0
# 275     Peter  Manager    2000.0 2015-08-31 2015-10-10      1003.0
#
#      ExpenseType                        SourceFile SourceSheet  \
# 149          4.0  testdata\example_expenses02.xlsx      Events
# 152          2.0  testdata\example_expenses02.xlsx      Events
# 271         11.0  testdata\example_expenses02.xlsx       Other
# 275         13.0  testdata\example_expenses02.xlsx       Other
#
#                Timestamp
# 149  2017-05-08 20:09:14
# 152  2017-05-08 20:09:14
# 271  2017-05-08 20:09:14
# 275  2017-05-08 20:09:14

# %%
#We create a dataframe where we accumulate exceptions

dfex =pd.DataFrame([])
dfex= dfex.append(dfex01)
dfex= dfex.append(dfex02)
dfex= dfex.append(dfex03)
dfex
# Out:
#          Name    Title  Expenses       Date Date Claim  CostCentre  \
# 144     Anshu  Manager    1000.0 2014-08-15 2014-09-24      1002.0
# 145     Arpad  Manager    1500.0 2014-07-01 2014-08-10      1002.0
# 146    Melany  Manager      -1.0 2014-07-01 2014-08-10      1002.0
# 147     Frank  Manager    1100.4 2015-01-01 2015-02-10      1002.0
# 149     Peter  Manager    2000.0 2015-08-31 2015-11-29      1002.0
# 154     Peter  Manager      99.0 2015-07-07 2015-10-24      1002.0
# 155     Anshu  Manager     167.2 2015-09-30 2016-01-28      1002.0
# 158     Peter  Manager     133.0 2015-07-07 2015-09-27      1002.0
# 159     Arpad  Manager     235.5 2015-03-15 2015-04-03      1002.0
# 160    Melany  Manager     220.4 2015-03-29 2015-05-09      1002.0
# 161     Anshu  Manager     169.0 2015-06-19 2015-09-12      1002.0
# 166     Arpad  Manager      11.8 2015-11-12 2016-01-16      1002.0
# 167     Anshu  Manager     221.3 2015-08-05 2015-10-06      1002.0
# 169     Anshu  Manager     138.5 2015-02-08 2015-04-19      1002.0
# 170     Peter  Manager       3.1 2015-05-10 2015-07-01      1002.0
# 149     Peter  Manager    2000.0 2015-08-31 2015-11-29      1002.0
# 152  Michaela   Senior     300.0 2015-04-20 2015-04-30      1002.0
# 271  Michaela   Senior     300.0 2015-04-20 2015-05-30      1003.0
# 275     Peter  Manager    2000.0 2015-08-31 2015-10-10      1003.0
#
#      ExpenseType                        SourceFile SourceSheet  \
# 144         12.0  testdata\example_expenses02.xlsx      Events
# 145          6.0  testdata\example_expenses02.xlsx      Events
# 146          9.0  testdata\example_expenses02.xlsx      Events
# 147          3.0  testdata\example_expenses02.xlsx      Events
# 149          4.0  testdata\example_expenses02.xlsx      Events
# 154          9.0  testdata\example_expenses02.xlsx      Events
# 155          2.0  testdata\example_expenses02.xlsx      Events
# 158          3.0  testdata\example_expenses02.xlsx      Events
# 159         11.0  testdata\example_expenses02.xlsx      Events
# 160          1.0  testdata\example_expenses02.xlsx      Events
# 161         10.0  testdata\example_expenses02.xlsx      Events
# 166          8.0  testdata\example_expenses02.xlsx      Events
# 167          9.0  testdata\example_expenses02.xlsx      Events
# 169          8.0  testdata\example_expenses02.xlsx      Events
# 170          3.0  testdata\example_expenses02.xlsx      Events
# 171         11.0  testdata\example_expenses02.xlsx      Events
# 172         13.0  testdata\example_expenses02.xlsx      Events
# 174          4.0  testdata\example_expenses02.xlsx      Events
# 175          4.0  testdata\example_expenses02.xlsx      Events
# 178          9.0  testdata\example_expenses02.xlsx      Events
# 179          9.0  testdata\example_expenses02.xlsx      Events
# 180          3.0  testdata\example_expenses02.xlsx      Events
# 182         10.0  testdata\example_expenses02.xlsx      Events
# 186          6.0  testdata\example_expenses02.xlsx      Events
# 187          7.0  testdata\example_expenses02.xlsx      Events
# 188          2.0  testdata\example_expenses02.xlsx      Events
# 192         10.0  testdata\example_expenses02.xlsx      Events
# 193          5.0  testdata\example_expenses02.xlsx      Events
# 198         13.0  testdata\example_expenses02.xlsx      Events
# 199          4.0  testdata\example_expenses02.xlsx      Events
# ..           ...                               ...         ...
# 425          6.0  testdata\example_expenses02.xlsx       Other
# 426          4.0  testdata\example_expenses02.xlsx       Other
# 427          1.0  testdata\example_expenses02.xlsx       Other
# 428          3.0  testdata\example_expenses02.xlsx       Other
# 429          2.0  testdata\example_expenses02.xlsx       Other
# 430          3.0  testdata\example_expenses02.xlsx       Other
# 431         12.0  testdata\example_expenses02.xlsx       Other
# 432          4.0  testdata\example_expenses02.xlsx       Other
# 433         12.0  testdata\example_expenses02.xlsx       Other
# 434          1.0  testdata\example_expenses02.xlsx       Other
# 435          7.0  testdata\example_expenses02.xlsx       Other
# 436          2.0  testdata\example_expenses02.xlsx       Other
# 437          9.0  testdata\example_expenses02.xlsx       Other
# 438          7.0  testdata\example_expenses02.xlsx       Other
# 439          3.0  testdata\example_expenses02.xlsx       Other
# 440          1.0  testdata\example_expenses02.xlsx       Other
# 441         12.0  testdata\example_expenses02.xlsx       Other
# 442          3.0  testdata\example_expenses02.xlsx       Other
# 443          4.0  testdata\example_expenses02.xlsx       Other
