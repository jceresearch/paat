# %%
import docx

# %%
document = docx.Document('./test_data/testfile.docx')

# %%
from docx.document import Document
from docx.oxml.table import CT_Tbl
from docx.oxml.text.paragraph import CT_P
from docx.table import _Cell, Table
from docx.text.paragraph import Paragraph

def iter_block_items(parent):
    """
    Yield each paragraph and table child within *parent*, in document order.
    Each returned value is an instance of either Table or Paragraph. *parent*
    would most commonly be a reference to a main Document object, but
    also works for a _Cell object, which itself can contain paragraphs and tables.
    """
    if isinstance(parent, Document):
        parent_elm = parent.element.body
    elif isinstance(parent, _Cell):
        parent_elm = parent._tc
    else:
        raise ValueError("something's not right")

    for child in parent_elm.iterchildren():
        if isinstance(child, CT_P):
            yield Paragraph(child, parent)
        elif isinstance(child, CT_Tbl):
            yield Table(child, parent)

# %%
for block in iter_block_items(document):
    print(block.text if isinstance(block, Paragraph) else '<table>')
# Out:
# Test document
#
# Section 1:  Cover sheet, This is a subtitle that is a bit too long for its own good
# (should be skipped)
#
# Section 2:  Executive summary
# This is a subtitle that is a bit too long for its own good, should be picked by the checker.
#
# 10 words:
# Lorem ipsum dolor sit amet consectetur adipiscing elit Donec rutrum.
# 20 Words:
# Lorem ipsum dolor sit amet, 20 consectetur adipiscing Ut eros libero condimentum nec purus nec, euismod tincidunt lectus Ut tincidunt.
# 30 words:
# Lorem ipsum dolor sit amet, 30 consectetur adipiscing Nunc accumsan quis felis non interdum; Morbi facilisis ullamcorper arcu et euismod vestibulum at ex dapibus tristique enim tempor ullamcorper sem Curabitur.
# 50 words:
# Lorem ipsum dolor sit amet, 50 consectetur adipiscing Integer diam orci, condimentum non mollis non lobortis id diam, Fusce et lorem vel lorem pharetra luctus a quis quam, Phasellus finibus, erat vitae cursus vulputate, lorem sem vulputate metus, eu bibendum orci nulla malesuada metus; Fusce nibh turpis, molestie eget neque.
# We noted that some of the points are badly written, lack of controls and governance  around the process of delivery
# One thing to note is that many people write poorly, it has been said many times that this is an outcome of the poor education system in UK. Not sure if this will be considered separate
# Another thing to highlight, highlighted in a previous sentence is that this is a long sentence and should be trimmered down.
# This time it has been attempted to have a paragraph with a very long sentence; with semi-colon and the like, very long indeed. Then a sentence to follow, also longer than your typical statement, I wonder BTW if there is a way of checking only for typos programmatically. Then some another longish sentence following to create a rather unreadable paragraph that would stand out in the report as a piece of rossetta stone to read.
# In order to test the warning feature, also in order to test commas.
# Hopefully this will be a sentence:
#
# Reasons for not flagging this bullet points: only 3 elements
# One
# Two
# Three
#
# This ones should be flagged
#
# Don’t know
# Don’t care
# Go away
# Please
# Aha
#
# This one will fail
# Again
# And again
# And again , gosh
# Dfasdfasd
# Asdfasdfasd
#
# One
# Two
# Thre
# Four
# Five
# Six
#
# This is another list
# Item 1
# Item 2
#
# Section 3: Findings
#
#
# This would be the equivalent of the body of the report
# Let me add here another even longer sentence to the mix; having semicolon, colons and the like, it will definitely pop up in the ratings, lets see how this goes, but it is getting long and longer and longer, and very much unending, I hope it is long enough
# Another relatively long one not too long but just about to see how it is picked  it should be about right no commas I will add one or two more.
#
# In our audits, we found that even trying processes were rubbish. We couldn’t test anything they told us, and even worse, they accepted all our finding with unrealistic dates, therefore the report will undoubtedly end up as a weak report , with significant number of actions to be completed by management.
# As a result of our audit, around  August, we found that even trying processes were rubbish. We couldn’t test anything they told us, and even worse, they accepted all our finding with unrealistic dates.
# As a result of our audit, around  August, we found that even trying processes were rubbish. We couldn’t test anything they told us, and even worse, they accepted all our finding with unrealistic dates.
# Another thing to highlight, highlighted in a previous sentence is that this is a long sentence and should be trim down.
#
# Two words bold test This is a test of a title too long based on having bold in only one or two  words lets see if the macro picks it
# All Bold is a test of a title too long based on having bold in the sentence lets see if the macro picks it
#
#
#
#
# Section 4: Root causes page
# This is an example, very long opening sentence with some introductory waffle and then a list of more concrete stuff, this should do the trick.
#
# We are going crazy with Bullets
# Bullet away
# Bullet away
# Bullet away
# Bullet away
# Bullet away
# Bullet away
# Bullet away
# Bullet away
# Bullet away
# Bullet away
# Bullet away
#
# Number away
# Number away
# Number away
# Number away
# Number away
# Number away
#
#
#
#
# Section 5: This is an appendix that nobody will ever read but hey ho
# Now this is an appendix section with some detail for completeness, maybe some tables and bullets, detail detail detail; this sentence should be huge.
#
# <table>
#
#
#
#
#
# We are going crazy with Bullets
# Bullet away
# Bullet away
# Bullet away
# Bullet away
# Bullet away
# Bullet away
# Bullet away
# Bullet away
# Bullet away
# Bullet away
# Bullet away
#
# Number away
# Number away
# Number away
# Number away
# Number away
# Number away
#
# Section 3: Findings
# Lorem ipsum dolor sit amet, 50 consectetur adipiscing Integer diam orci, condimentum non mollis non lobortis id diam, Fusce et lorem vel lorem pharetra luctus a quis quam, Phasellus finibus, erat vitae cursus vulputate, lorem sem vulputate metus, eu bibendum orci nulla malesuada metus; Fusce nibh turpis, molestie eget neque .
# Section 3: Findings
#
# Super Long Sentence ipsum dolor sit amet, 50 consectetur adipiscing Integer diam orci, condimentum non mollis non lobortis id diam, Fusce et lorem vel lorem pharetra luctus a quis quam, Phasellus finibus, erat vitae cursus vulputate, lorem sem vulputate metus, eu bibendum orci nulla malesuada metus; Fusce nibh turpis, molestie eget neque Lorem ipsum dolor sit amet, 50 consectetur adipiscing Integer diam orci, condimentum non mollis non lobortis id diam, Fusce et lorem vel lorem pharetra luctus a quis quam, Phasellus finibus, erat vitae cursus vulputate, lorem sem vulputate metus, eu bibendum orci nulla malesuada metus; Fusce nibh turpis, molestie eget neque .
#
#
# Appendix 2
#
# Super Long Sentence ipsum dolor sit amet, 50 consectetur adipiscing Integer diam orci, condimentum non mollis non lobortis id diam, Fusce et lorem vel lorem pharetra luctus a quis quam, Phasellus finibus, erat vitae cursus vulputate, lorem sem vulputate metus, eu bibendum orci nulla malesuada metus; Fusce nibh turpis, molestie eget neque Lorem ipsum dolor sit amet, 50 consectetur adipiscing Integer diam orci, condimentum non mollis non lobortis id diam, Fusce et lorem vel lorem pharetra luctus a quis quam, Phasellus finibus, erat vitae cursus vulputate, lorem sem vulputate metus, eu bibendum orci nulla malesuada metus; Fusce nibh turpis, molestie eget neque .
# There are some concerns about the governance of this process

# %%
# This snippet is an example of using the forc bayoo-docx which allows creating comments, but need to install the specific fork
#import docx
#Successfully installed bayoo-docx-0.2.5
raise SystemExit("Stop right there!")
import docx
import re
from docx.shared import Pt
from docx.shared import Emu

doc = docx.Document('testfile.docx')
n=1
for i in doc.paragraphs:
    word_count = len(re.findall(r'\w+', i.text))
    font_is_bold=False
    for r in i.runs:
        font_list=[]
        font = r.font
        try: 
            font_size= Emu(font.size).pt
        except:
            font_size=0
      
        font_is_bold=font.bold
        font_list.append(font_size)
        max_font=max(font_list)
    print(n, word_count, font_list,max_font,font_is_bold)
    print(i.text)
    if n==9:
        i.add_comment("My comment")
        print("Added comment")
    n +=1
    
doc.save ("Test python.docx")
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Stop right there!
# C:\Python37\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
