# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots()
#s = pd.Series(np.random.normal(0,100, 10000))
s = pd.Series(np.random.randint(0, 30, size=200))
#p = s.plot(kind='hist', bins=50, color='orange')
#p = s.plot(kind='hist', density=True,cumulative=True ,bins=50, color='orange', width=.5)
counts, bins, bars= plt.hist(s, density=True,cumulative=True ,bins=50, color='orange', width=.5)


plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6c0f93f396a4> in <module>
#      23         min_distance = tmp
#      24         index_of_bar_to_label = i
# ---> 25 p.patches[index_of_bar_to_label].set_color('b')
#      26 p.axhline(y=0.9, color='r', linestyle='-')
#      27 rect=p.patches[index_of_bar_to_label]
#
# NameError: name 'p' is not defined

# %%
bar_value_to_label = 22
min_distance = float("inf")  # initialize min_distance with infinity
index_of_bar_to_label = 0
for i, rectangle in enumerate(p.patches):  # iterate over every bar
    
    
    
    tmp = abs(  # tmp = distance from middle of the bar to bar_value_to_label
        (rectangle.get_x() +
            (rectangle.get_width() * (1 / 2))) - bar_value_to_label)
    if tmp < min_distance:  # we are searching for the bar with x cordinate
                            # closest to bar_value_to_label
        min_distance = tmp
        index_of_bar_to_label = i
p.patches[index_of_bar_to_label].set_color('b')
p.axhline(y=0.9, color='r', linestyle='-')
rect=p.patches[index_of_bar_to_label]
y_value = rect.get_height()
x_value = rect.get_x() + rect.get_width() / 2
label= rect.get_y()
plt.annotate(label,(x_value,y_value)
  ,xytext=(0,5),  textcoords="offset points"   
          
          )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-52ee5638be15> in <module>
#       2 min_distance = float("inf")  # initialize min_distance with infinity
#       3 index_of_bar_to_label = 0
# ----> 4 for i, rectangle in enumerate(p.patches):  # iterate over every bar
#       5
#       6
#
# NameError: name 'p' is not defined
